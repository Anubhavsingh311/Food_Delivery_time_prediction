# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/kaggle/input/datasets/anubhavsingh311/food-delivery-dataset/train.csv")
print(df.shape[0])
print(df.shape[1])
# Out:
# 45593
# 20

# %%
df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
# 1                    77.813237  25-03-2022    19:45:00          19:50:00
# 2                    77.688400  19-03-2022    08:30:00          08:45:00
# 3                    77.026494  05-04-2022    18:00:00          18:10:00
# 4                    80.289982  26-03-2022    13:30:00          13:45:00
#
#        Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0       conditions Sunny                High                   2
# 1      conditions Stormy                 Jam                   2
# 2  conditions Sandstorms                 Low                   0
# 3       conditions Sunny              Medium                   0
# 4      conditions Cloudy                High                   1
#
#   Type_of_order Type_of_vehicle multiple_deliveries Festival            City  \
# 0        Snack      motorcycle                    0      No           Urban
# 1        Snack         scooter                    1      No   Metropolitian
# 2       Drinks      motorcycle                    1      No           Urban
# 3       Buffet      motorcycle                    1      No   Metropolitian
# 4        Snack         scooter                    1      No   Metropolitian
#
#   Time_taken(min)
# 0        (min) 24
# 1        (min) 33
# 2        (min) 26
# 3        (min) 21
# 4        (min) 30

# %%
df.isna().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
#Cleaning Part
df_temp = df.copy()
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
#  12  Road_traffic_density         45593 non-null  object
#  13  Vehicle_condition            45593 non-null  int64
#  14  Type_of_order                45593 non-null  object
#  15  Type_of_vehicle              45593 non-null  object
#  16  multiple_deliveries          45593 non-null  object
#  17  Festival                     45593 non-null  object
#  18  City                         45593 non-null  object
#  19  Time_taken(min)              45593 non-null  object
# dtypes: float64(4), int64(1), object(15)
# memory usage: 7.0+ MB

# %%
for col in df_temp.select_dtypes(include="object").columns:
    df_temp[col] = df_temp[col].str.strip()

# %%
df_temp = df_temp.replace("NaN", np.nan)
df_temp.isin(["NaN"]).any()
# Out:
# ID                             False
# Delivery_person_ID             False
# Delivery_person_Age            False
# Delivery_person_Ratings        False
# Restaurant_latitude            False
# Restaurant_longitude           False
# Delivery_location_latitude     False
# Delivery_location_longitude    False
# Order_Date                     False
# Time_Orderd                    False
# Time_Order_picked              False
# Weatherconditions              False
# Road_traffic_density           False
# Vehicle_condition              False
# Type_of_order                  False
# Type_of_vehicle                False
# multiple_deliveries            False
# Festival                       False
# City                           False
# Time_taken(min)                False
# dtype: bool

# %%
df_temp["Weatherconditions"].value_counts()
# Out:
# Weatherconditions
# conditions Fog           7654
# conditions Stormy        7586
# conditions Cloudy        7536
# conditions Sandstorms    7495
# conditions Windy         7422
# conditions Sunny         7284
# conditions NaN            616
# Name: count, dtype: int64

# %%
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions NaN", np.nan)
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions Fog", "Fog")
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions Stormy", "Stormy")
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions Cloudy", "Cloudy")
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions Sandstorms", "Sandstorms")
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions Windy", "Windy")
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].replace("conditions Sunny", "Sunny")
df_temp.head()
# Out:
#        ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                  37                     4.9
# 1  0xb379     BANGRES18DEL02                  34                     4.5
# 2  0x5d6d     BANGRES19DEL01                  23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                  38                     4.7
# 4  0x70a2     CHENRES12DEL01                  32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    75.912471  19-03-2022    11:30:00          11:45:00
# 1                    77.813237  25-03-2022    19:45:00          19:50:00
# 2                    77.688400  19-03-2022    08:30:00          08:45:00
# 3                    77.026494  05-04-2022    18:00:00          18:10:00
# 4                    80.289982  26-03-2022    13:30:00          13:45:00
#
#   Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0             Sunny                 High                  2         Snack
# 1            Stormy                  Jam                  2         Snack
# 2        Sandstorms                  Low                  0        Drinks
# 3             Sunny               Medium                  0        Buffet
# 4            Cloudy                 High                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City Time_taken(min)
# 0      motorcycle                   0       No          Urban        (min) 24
# 1         scooter                   1       No  Metropolitian        (min) 33
# 2      motorcycle                   1       No          Urban        (min) 26
# 3      motorcycle                   1       No  Metropolitian        (min) 21
# 4         scooter                   1       No  Metropolitian        (min) 30

# %%
df_temp["Delivery_person_Age"] = pd.to_numeric(
    df_temp["Delivery_person_Age"],
    errors="coerce"
)

df_temp["Delivery_person_Ratings"] = pd.to_numeric(
    df_temp["Delivery_person_Ratings"],
    errors="coerce"
)

df_temp["multiple_deliveries"] = pd.to_numeric(
    df_temp["multiple_deliveries"],
    errors="coerce"
)

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          43739 non-null  float64
#  3   Delivery_person_Ratings      43685 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  43862 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            44977 non-null  object
#  12  Road_traffic_density         44992 non-null  object
#  13  Vehicle_condition            45593 non-null  int64
#  14  Type_of_order                45593 non-null  object
#  15  Type_of_vehicle              45593 non-null  object
#  16  multiple_deliveries          44600 non-null  float64
#  17  Festival                     45365 non-null  object
#  18  City                         44393 non-null  object
#  19  Time_taken(min)              45593 non-null  object
# dtypes: float64(7), int64(1), object(12)
# memory usage: 7.0+ MB

# %%
df_temp["Time_taken(min)"] = (
    df_temp["Time_taken(min)"]
    .str.replace("(min)", "", regex=False)
    .str.strip()
)

df_temp["Time_taken(min)"] = pd.to_numeric(
    df_temp["Time_taken(min)"],
    errors="coerce"
)

# %%
df_temp["Time_taken(min)"].head()
# Out:
# 0    24
# 1    33
# 2    26
# 3    21
# 4    30
# Name: Time_taken(min), dtype: int64

# %%
df_temp["Order_Date"] = pd.to_datetime(
    df_temp["Order_Date"],
    format="%d-%m-%Y",
    errors="coerce"
)
df_temp["Time_Orderd"] = pd.to_datetime(
    df_temp["Time_Orderd"],
    format="%H:%M:%S",
    errors="coerce"
)

df_temp["Time_Order_picked"] = pd.to_datetime(
    df_temp["Time_Order_picked"],
    format="%H:%M:%S",
    errors="coerce"
)

# %%
df_temp.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date         Time_Orderd  \
# 0                    75.912471 2022-03-19 1900-01-01 11:30:00
# 1                    77.813237 2022-03-25 1900-01-01 19:45:00
# 2                    77.688400 2022-03-19 1900-01-01 08:30:00
# 3                    77.026494 2022-04-05 1900-01-01 18:00:00
# 4                    80.289982 2022-03-26 1900-01-01 13:30:00
#
#     Time_Order_picked Weatherconditions Road_traffic_density  \
# 0 1900-01-01 11:45:00             Sunny                 High
# 1 1900-01-01 19:50:00            Stormy                  Jam
# 2 1900-01-01 08:45:00        Sandstorms                  Low
# 3 1900-01-01 18:10:00             Sunny               Medium
# 4 1900-01-01 13:45:00            Cloudy                 High
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 0                  2         Snack      motorcycle                  0.0
# 1                  2         Snack         scooter                  1.0
# 2                  0        Drinks      motorcycle                  1.0
# 3                  0        Buffet      motorcycle                  1.0
# 4                  1         Snack         scooter                  1.0
#
#   Festival           City  Time_taken(min)
# 0       No          Urban               24
# 1       No  Metropolitian               33
# 2       No          Urban               26
# 3       No  Metropolitian               21
# 4       No  Metropolitian               30

# %%
print("Missing values:")
print(df_temp.isna().sum())
# Out:
# Missing values:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions               616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken(min)                   0
# dtype: int64

# %%
df_temp["Delivery_person_Age"] = df_temp["Delivery_person_Age"].fillna(df_temp["Delivery_person_Age"].median())
df_temp["Delivery_person_Age"].isna().sum()
# Out:
# np.int64(0)

# %%
df_temp["Delivery_person_Ratings"] = df_temp["Delivery_person_Ratings"].fillna(df_temp["Delivery_person_Ratings"].median())
df_temp["Delivery_person_Ratings"].isna().sum()
# Out:
# np.int64(0)

# %%
df_temp["multiple_deliveries"] = df_temp["multiple_deliveries"].fillna(df_temp["multiple_deliveries"].mode()[0])
df_temp["multiple_deliveries"].isna().sum()
# Out:
# np.int64(0)

# %%
df_temp["Weatherconditions"] = df_temp["Weatherconditions"].fillna("Unknown")
df_temp["Road_traffic_density"] = df_temp["Road_traffic_density"].fillna("Unknown")
df_temp["Festival"] = df_temp["Festival"].fillna("Unknown")
df_temp["City"] = df_temp["City"].fillna("Unknown")
df_temp.isna().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken(min)                   0
# dtype: int64

# %%
#Feature Engineering
#1) Calculating distance using Haversine formula
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371 

    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = (
        np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    )

    c = 2 * np.arcsin(np.sqrt(a))

    return R * c

# %%
df_temp["distance_km"] = haversine_distance(
    df_temp["Restaurant_latitude"],
    df_temp["Restaurant_longitude"],
    df_temp["Delivery_location_latitude"],
    df_temp["Delivery_location_longitude"]
)

# %%
df_temp.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date         Time_Orderd  ...  \
# 0                    75.912471 2022-03-19 1900-01-01 11:30:00  ...
# 1                    77.813237 2022-03-25 1900-01-01 19:45:00  ...
# 2                    77.688400 2022-03-19 1900-01-01 08:30:00  ...
# 3                    77.026494 2022-04-05 1900-01-01 18:00:00  ...
# 4                    80.289982 2022-03-26 1900-01-01 13:30:00  ...
#
#   Weatherconditions Road_traffic_density Vehicle_condition  Type_of_order  \
# 0             Sunny                 High                 2          Snack
# 1            Stormy                  Jam                 2          Snack
# 2        Sandstorms                  Low                 0         Drinks
# 3             Sunny               Medium                 0         Buffet
# 4            Cloudy                 High                 1          Snack
#
#   Type_of_vehicle multiple_deliveries  Festival           City  \
# 0      motorcycle                 0.0        No          Urban
# 1         scooter                 1.0        No  Metropolitian
# 2      motorcycle                 1.0        No          Urban
# 3      motorcycle                 1.0        No  Metropolitian
# 4         scooter                 1.0        No  Metropolitian
#
#   Time_taken(min)  distance_km
# 0              24     3.025149
# 1              33    20.183530
# 2              26     1.552758
# 3              21     7.790401
# 4              30     6.210138
#
# [5 rows x 21 columns]

# %%
df_temp["distance_km"].describe()
# Out:
# count    45593.000000
# mean        99.303911
# std       1099.731281
# min          1.465067
# 25%          4.663493
# 50%          9.264281
# 75%         13.763977
# max      19692.674606
# Name: distance_km, dtype: float64

# %%
Q1 = df_temp["distance_km"].quantile(0.25)
Q3 = df_temp["distance_km"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_temp = df_temp[(df_temp["distance_km"] >= lower_bound) & (df_temp["distance_km"] <= upper_bound)].copy()
df_temp["distance_km"].describe()
# Out:
# count    45162.000000
# mean         9.735396
# std          5.608508
# min          1.465067
# 25%          4.663412
# 50%          9.220209
# 75%         13.681490
# max         20.969489
# Name: distance_km, dtype: float64

# %%
print(len(df)- len(df_temp))
# Out:
# 431

# %%
df_temp["Order_Hour"] = df_temp["Time_Orderd"].dt.hour
df_temp["Order_Minute"] = df_temp["Time_Orderd"].dt.minute

df_temp["Order_Day"] = df_temp["Order_Date"].dt.day
df_temp["Order_Month"] = df_temp["Order_Date"].dt.month
df_temp["Order_DayOfWeek"] = df_temp["Order_Date"].dt.dayofweek

df_temp.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                 37.0                      4.9
# 1  0xb379     BANGRES18DEL02                 34.0                      4.5
# 2  0x5d6d     BANGRES19DEL01                 23.0                      4.4
# 3  0x7a6a    COIMBRES13DEL02                 38.0                      4.7
# 4  0x70a2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date         Time_Orderd  ...  \
# 0                    75.912471 2022-03-19 1900-01-01 11:30:00  ...
# 1                    77.813237 2022-03-25 1900-01-01 19:45:00  ...
# 2                    77.688400 2022-03-19 1900-01-01 08:30:00  ...
# 3                    77.026494 2022-04-05 1900-01-01 18:00:00  ...
# 4                    80.289982 2022-03-26 1900-01-01 13:30:00  ...
#
#   multiple_deliveries Festival           City  Time_taken(min) distance_km  \
# 0                 0.0       No          Urban               24    3.025149
# 1                 1.0       No  Metropolitian               33   20.183530
# 2                 1.0       No          Urban               26    1.552758
# 3                 1.0       No  Metropolitian               21    7.790401
# 4                 1.0       No  Metropolitian               30    6.210138
#
#   Order_Hour  Order_Minute Order_Day Order_Month  Order_DayOfWeek
# 0       11.0          30.0        19           3                5
# 1       19.0          45.0        25           3                4
# 2        8.0          30.0        19           3                5
# 3       18.0           0.0         5           4                1
# 4       13.0          30.0        26           3                5
#
# [5 rows x 26 columns]

# %%
def get_time_period(hour):
    if 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    else:
        return "Night"

df_temp["Time_Period"] = df_temp["Order_Hour"].apply(get_time_period)

df_temp["Time_Period"].value_counts()
# Out:
# Time_Period
# Evening      17833
# Night        15605
# Morning       7690
# Afternoon     4034
# Name: count, dtype: int64

# %%
df_temp["Is_Weekend"] = df_temp["Order_DayOfWeek"].isin([5, 6]).astype(int)
df_temp["Is_Weekend"].value_counts()
# Out:
# Is_Weekend
# 0    32734
# 1    12428
# Name: count, dtype: int64

# %%
df_temp["Time_taken(min)"].describe()
# Out:
# count    45162.000000
# mean        26.298038
# std          9.383733
# min         10.000000
# 25%         19.000000
# 50%         26.000000
# 75%         32.000000
# max         54.000000
# Name: Time_taken(min), dtype: float64

# %%
categorical_cols = df_temp.select_dtypes(include="object").columns

for col in categorical_cols:
    print(df_temp[col].value_counts())
# Out:
# ID
# 0x5fb2    1
# 0x4607    1
# 0xb379    1
# 0x5d6d    1
# 0x7a6a    1
#          ..
# 0x3af3    1
# 0xdb64    1
# 0xc8b6    1
# 0x2784    1
# 0xd987    1
# Name: count, Length: 45162, dtype: int64
# Delivery_person_ID
# PUNERES01DEL01      67
# JAPRES11DEL02       67
# JAPRES03DEL01       66
# VADRES11DEL02       66
# RANCHIRES02DEL01    66
#                     ..
# KOLRES04DEL03        7
# KOCRES16DEL03        6
# KOLRES09DEL03        6
# KOLRES010DEL03       6
# BHPRES010DEL03       5
# Name: count, Length: 1320, dtype: int64
# Weatherconditions
# Fog           7604
# Stormy        7544
# Cloudy        7485
# Sandstorms    7442
# Windy         7382
# Sunny         7238
# Unknown        467
# Name: count, dtype: int64
# Road_traffic_density
# Low        15372
# Jam        14050
# Medium     10886
# High        4400
# Unknown      454
# Name: count, dtype: int64
# Type_of_order
# Snack     11428
# Meal      11332
# Drinks    11225
# Buffet    11177
# Name: count, dtype: int64
# Type_of_vehicle
# motorcycle          26236
# scooter             15125
# electric_scooter     3750
# bicycle                51
# Name: count, dtype: int64
# Festival
# No         44048
# Yes          886
# Unknown      228
# Name: count, dtype: int64
# City
# Metropolitian    33785
# Urban            10032
# Unknown           1183
# Semi-Urban         162
# Name: count, dtype: int64
# Time_Period
# Evening      17833
# Night        15605
# Morning       7690
# Afternoon     4034
# Name: count, dtype: int64

# %%
print("Shape:", df_temp.shape)

print("\nMissing values:")
print(df_temp.isna().sum())

print("\nDuplicate rows:", df_temp.duplicated().sum())

print("\nDuplicate IDs:", df_temp["ID"].duplicated().sum())

print("\nData types:")
print(df_temp.dtypes)
# Out:
# Shape: (45162, 28)
#
# Missing values:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1456
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken(min)                   0
# distance_km                       0
# Order_Hour                     1456
# Order_Minute                   1456
# Order_Day                         0
# Order_Month                       0
# Order_DayOfWeek                   0
# Time_Period                       0
# Is_Weekend                        0
# dtype: int64
#
# Duplicate rows: 0
#
# Duplicate IDs: 0
#
# Data types:
# ID                                     object
# Delivery_person_ID                     object
# Delivery_person_Age                   float64
# Delivery_person_Ratings               float64
# Restaurant_latitude                   float64
# Restaurant_longitude                  float64
# Delivery_location_latitude            float64
# Delivery_location_longitude           float64
# Order_Date                     datetime64[ns]
# Time_Orderd                    datetime64[ns]
# Time_Order_picked              datetime64[ns]
# Weatherconditions                      object
# Road_traffic_density                   object
# Vehicle_condition                       int64
# Type_of_order                          object
# Type_of_vehicle                        object
# multiple_deliveries                   float64
# Festival                               object
# City                                   object
# Time_taken(min)                         int64
# distance_km                           float64
# Order_Hour                            float64
# Order_Minute                          float64
# Order_Day                               int32
# Order_Month                             int32
# Order_DayOfWeek                         int32
# Time_Period                            object
# Is_Weekend                              int64
# dtype: object

# %%
def get_time_period(hour):
    if pd.isna(hour):
        return "Unknown"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    else:
        return "Night"


df_temp["Time_Period"] = df_temp["Order_Hour"].apply(get_time_period)
df_temp["Time_Period"].value_counts()
# Out:
# Time_Period
# Evening      17833
# Night        14149
# Morning       7690
# Afternoon     4034
# Unknown       1456
# Name: count, dtype: int64

# %%
df_temp["Time_Order_Missing"] = df_temp["Time_Orderd"].isna().astype(int)
df_temp["Time_Order_Missing"].value_counts()
# Out:
# Time_Order_Missing
# 0    43706
# 1     1456
# Name: count, dtype: int64

# %%
df_temp["Order_Hour"] = df_temp["Order_Hour"].fillna(df_temp["Order_Hour"].median())
df_temp["Order_Minute"] = df_temp["Order_Minute"].fillna(df_temp["Order_Minute"].median())
df_temp[["Order_Hour", "Order_Minute"]].isna().sum()
# Out:
# Order_Hour      0
# Order_Minute    0
# dtype: int64

# %%
#Pickup delay time calc FE
df_temp["Pickup_Delay_Min"] = (df_temp["Time_Order_picked"] - df_temp["Time_Orderd"]).dt.total_seconds() / 60
df_temp["Pickup_Delay_Missing"] = df_temp["Pickup_Delay_Min"].isna().astype(int)
df_temp["Pickup_Delay_Min"].describe()
# Out:
# count    43706.000000
# mean       -17.323251
# std        196.229808
# min      -1435.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         15.000000
# Name: Pickup_Delay_Min, dtype: float64

# %%
df_temp["Pickup_Delay_Min"] = df_temp["Pickup_Delay_Min"].fillna(df_temp["Pickup_Delay_Min"].median())
df_temp["Pickup_Delay_Min"].isna().sum()
# Out:
# np.int64(0)

# %%
print("Negative pickup delays:")
print((df_temp["Pickup_Delay_Min"] < 0).sum())

print("\nPickup delay statistics:")
print(df_temp["Pickup_Delay_Min"].describe())
# Out:
# Negative pickup delays:
# 829
#
# Pickup delay statistics:
# count    45162.000000
# mean       -16.442363
# std        193.100971
# min      -1435.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         15.000000
# Name: Pickup_Delay_Min, dtype: float64

# %%
df_temp["Pickup_Hour"] = df_temp["Time_Order_picked"].dt.hour
df_temp["Pickup_Minute"] = df_temp["Time_Order_picked"].dt.minute
df_temp[["Pickup_Hour", "Pickup_Minute"]].isna().sum()
# Out:
# Pickup_Hour      0
# Pickup_Minute    0
# dtype: int64

# %%
df_temp["Pickup_Time_Period"] = df_temp["Pickup_Hour"].apply(get_time_period)
df_temp["Pickup_Time_Period"].value_counts()
# Out:
# Pickup_Time_Period
# Evening      17707
# Night        15455
# Morning       7572
# Afternoon     4428
# Name: count, dtype: int64

# %%
# Correct midnight rollover in pickup delay
df_temp.loc[df_temp["Pickup_Delay_Min"] < 0,"Pickup_Delay_Min"] += 24 * 60

# %%
print("Negative pickup delays:",
      (df_temp["Pickup_Delay_Min"] < 0).sum())

print("Pickup delay statistics:")
print(df_temp["Pickup_Delay_Min"].describe())
# Out:
# Negative pickup delays: 0
# Pickup delay statistics:
# count    45162.000000
# mean         9.990479
# std          4.021311
# min          5.000000
# 25%          5.000000
# 50%         10.000000
# 75%         15.000000
# max         15.000000
# Name: Pickup_Delay_Min, dtype: float64

# %%
print(df_temp["Pickup_Delay_Min"].isna().sum())
# Out:
# 0

# %%
numeric_cols = [
    "Delivery_person_Age",
    "Delivery_person_Ratings",
    "distance_km",
    "Pickup_Delay_Min"
]

for col in numeric_cols:
    Q1 = df_temp[col].quantile(0.25)
    Q3 = df_temp[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = ((df_temp[col] < lower_bound) |
                (df_temp[col] > upper_bound)).sum()

    print(f"{col}: {outliers}")
# Out:
# Delivery_person_Age: 31
# Delivery_person_Ratings: 2453
# distance_km: 0
# Pickup_Delay_Min: 0

# %%
Q1 = df_temp["distance_km"].quantile(0.25)
Q3 = df_temp["distance_km"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_temp = df_temp[(df_temp["distance_km"] >= lower_bound) & (df_temp["distance_km"] <= upper_bound)]

# %%
Q1 = df_temp["Delivery_person_Age"].quantile(0.25)
Q3 = df_temp["Delivery_person_Age"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

before = len(df_temp)

df_temp = df_temp[
    (df_temp["Delivery_person_Age"] >= lower_bound) &
    (df_temp["Delivery_person_Age"] <= upper_bound)
]

after = len(df_temp)

print("Rows removed:", before - after)
print("Shape:", df_temp.shape)
# Out:
# Rows removed: 31
# Shape: (45131, 34)

# %%
Q1 = df_temp["Delivery_person_Ratings"].quantile(0.25)
Q3 = df_temp["Delivery_person_Ratings"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

before = len(df_temp)

df_temp = df_temp[
    (df_temp["Delivery_person_Ratings"] >= lower_bound) &
    (df_temp["Delivery_person_Ratings"] <= upper_bound)
]

after = len(df_temp)

print("Rows removed:", before - after)
print("New shape:", df_temp.shape)
# Out:
# Rows removed: 2422
# New shape: (42709, 34)

# %%
outliers = ((df_temp["Delivery_person_Ratings"] < lower_bound) | (df_temp["Delivery_person_Ratings"] > upper_bound)).sum()
print("Remaining outliers:", outliers)
# Out:
# Remaining outliers: 0

# %%
print("Target outlier values:")
print(
    df_temp.loc[
        df_temp["Time_taken(min)"] > 49,
        "Time_taken(min)"
    ].value_counts().sort_index()
)
# Out:
# Target outlier values:
# Time_taken(min)
# 50    65
# 51    81
# 52    71
# 53    86
# 54    78
# Name: count, dtype: int64

# %%
print(
    df_temp.loc[
        df_temp["Time_taken(min)"] > 49,
        [
            "Delivery_person_Age",
            "Delivery_person_Ratings",
            "distance_km",
            "Weatherconditions",
            "Road_traffic_density",
            "Vehicle_condition",
            "multiple_deliveries",
            "Festival",
            "City",
            "Pickup_Delay_Min",
            "Time_taken(min)"
        ]
    ].head(20)
)
# Out:
#       Delivery_person_Age  Delivery_person_Ratings  distance_km  \
# 43                   37.0                      4.7    13.682516
# 142                  31.0                      4.2    17.076259
# 188                  38.0                      4.3    13.989917
# 266                  35.0                      4.9    10.417066
# 275                  34.0                      4.9    17.075594
# 479                  33.0                      4.6    13.583086
# 722                  31.0                      4.4    10.756273
# 778                  20.0                      4.5     6.037474
# 1026                 35.0                      4.6    19.364275
# 1192                 30.0                      4.9    14.152801
# 1358                 38.0                      4.1    10.445548
# 1527                 37.0                      4.8    12.099355
# 1554                 36.0                      4.1    12.256076
# 1712                 31.0                      4.6    16.852689
# 1762                 28.0                      4.3     7.790161
# 1938                 33.0                      4.6    20.252924
# 2047                 21.0                      4.5     6.049956
# 2315                 36.0                      4.4    13.582584
# 2373                 31.0                      4.9    17.074786
# 2417                 39.0                      4.9    11.007735
#
#      Weatherconditions Road_traffic_density  Vehicle_condition  \
# 43          Sandstorms                  Jam                  0
# 142         Sandstorms                  Jam                  0
# 188         Sandstorms                  Jam                  0
# 266             Cloudy                  Jam                  0
# 275         Sandstorms                  Jam                  0
# 479              Windy                  Jam                  0
# 722             Stormy                  Jam                  0
# 778              Sunny                 High                  0
# 1026               Fog                  Jam                  0
# 1192               Fog                  Jam                  0
# 1358        Sandstorms                  Jam                  0
# 1527               Fog                  Jam                  0
# 1554            Stormy                  Jam                  0
# 1712        Sandstorms                  Jam                  0
# 1762             Sunny                  Jam                  0
# 1938            Cloudy                  Jam                  0
# 2047             Sunny                 High                  0
# 2315            Stormy                  Jam                  0
# 2373               Fog                  Jam                  0
# 2417             Windy                  Jam                  0
#
#       multiple_deliveries Festival           City  Pickup_Delay_Min  \
# 43                    3.0       No  Metropolitian               5.0
# 142                   1.0       No  Metropolitian              10.0
# 188                   1.0      Yes     Semi-Urban              10.0
# 266                   2.0       No  Metropolitian              15.0
# 275                   3.0      Yes          Urban              15.0
# 479                   2.0      Yes          Urban              10.0
# 722                   1.0      Yes  Metropolitian               5.0
# 778                   1.0       No  Metropolitian              15.0
# 1026                  1.0      Yes  Metropolitian               5.0
# 1192                  1.0      Yes  Metropolitian               5.0
# 1358                  1.0       No  Metropolitian               5.0
# 1527                  1.0       No  Metropolitian               5.0
# 1554                  3.0       No  Metropolitian               5.0
# 1712                  1.0       No     Semi-Urban              10.0
# 1762                  3.0       No     Semi-Urban               5.0
# 1938                  2.0       No  Metropolitian              15.0
# 2047                  2.0      Yes  Metropolitian              15.0
# 2315                  3.0       No  Metropolitian              10.0
# 2373                  0.0       No  Metropolitian               5.0
# 2417                  0.0      Yes     Semi-Urban              15.0
#
#       Time_taken(min)
# 43                 52
# 142                50
# 188                54
# 266                53
# 275                50
# 479                50
# 722                53
# 778                51
# 1026               51
# 1192               53
# 1358               50
# 1527               52
# 1554               51
# 1712               52
# 1762               50
# 1938               52
# 2047               52
# 2315               51
# 2373               54
# 2417               50

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_temp["Time_taken(min)"], bins=30)
plt.xlabel("Time Taken (minutes)")
plt.ylabel("Frequency")
plt.title("Distribution of Delivery Time")
plt.show()

# %%
for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df_temp[col].value_counts(dropna=False))
# Out:
# --- ID ---
# ID
# 0x5fb2    1
# 0x4607    1
# 0xb379    1
# 0x5d6d    1
# 0x7a6a    1
#          ..
# 0xcdcd    1
# 0x1102    1
# 0x9eb2    1
# 0x95b4    1
# 0x9bb4    1
# Name: count, Length: 42709, dtype: int64
#
# --- Delivery_person_ID ---
# Delivery_person_ID
# JAPRES11DEL02       65
# VADRES08DEL02       64
# PUNERES01DEL01      63
# RANCHIRES02DEL02    63
# COIMBRES010DEL02    63
#                     ..
# BHPRES08DEL03        6
# BHPRES06DEL03        6
# BHPRES010DEL03       5
# KOLRES09DEL03        5
# KOLRES010DEL03       4
# Name: count, Length: 1320, dtype: int64
#
# --- Weatherconditions ---
# Weatherconditions
# Fog           7308
# Cloudy        7138
# Stormy        7076
# Sandstorms    6982
# Windy         6979
# Sunny         6818
# Unknown        408
# Name: count, dtype: int64
#
# --- Road_traffic_density ---
# Road_traffic_density
# Low        14665
# Jam        12975
# Medium     10456
# High        4218
# Unknown      395
# Name: count, dtype: int64
#
# --- Type_of_order ---
# Type_of_order
# Snack     10836
# Meal      10691
# Drinks    10610
# Buffet    10572
# Name: count, dtype: int64
#
# --- Type_of_vehicle ---
# Type_of_vehicle
# motorcycle          24899
# scooter             14217
# electric_scooter     3553
# bicycle                40
# Name: count, dtype: int64
#
# --- Festival ---
# Festival
# No         41719
# Yes          762
# Unknown      228
# Name: count, dtype: int64
#
# --- City ---
# City
# Metropolitian    31749
# Urban             9676
# Unknown           1140
# Semi-Urban         144
# Name: count, dtype: int64
#
# --- Time_Period ---
# Time_Period
# Evening      16741
# Night        13177
# Morning       7498
# Afternoon     3896
# Unknown       1397
# Name: count, dtype: int64

# %%
print("Total columns:", len(df_temp.columns))

for i, col in enumerate(df_temp.columns, 1):
    print(f"{i}. {col}")
# Out:
# Total columns: 34
# 1. ID
# 2. Delivery_person_ID
# 3. Delivery_person_Age
# 4. Delivery_person_Ratings
# 5. Restaurant_latitude
# 6. Restaurant_longitude
# 7. Delivery_location_latitude
# 8. Delivery_location_longitude
# 9. Order_Date
# 10. Time_Orderd
# 11. Time_Order_picked
# 12. Weatherconditions
# 13. Road_traffic_density
# 14. Vehicle_condition
# 15. Type_of_order
# 16. Type_of_vehicle
# 17. multiple_deliveries
# 18. Festival
# 19. City
# 20. Time_taken(min)
# 21. distance_km
# 22. Order_Hour
# 23. Order_Minute
# 24. Order_Day
# 25. Order_Month
# 26. Order_DayOfWeek
# 27. Time_Period
# 28. Is_Weekend
# 29. Time_Order_Missing
# 30. Pickup_Delay_Min
# 31. Pickup_Delay_Missing
# 32. Pickup_Hour
# 33. Pickup_Minute
# 34. Pickup_Time_Period

# %%
#Drop the columns for proper data
drop_cols = [
    "ID",
    "Delivery_person_ID",
    "Restaurant_latitude",
    "Restaurant_longitude",
    "Delivery_location_latitude",
    "Delivery_location_longitude",
    "Order_Date",
    "Time_Orderd",
    "Time_Order_picked"
]

df = df_temp.drop(columns=drop_cols).copy()

print("Shape after dropping columns:", df.shape)

print("\nRemaining columns:")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# Shape after dropping columns: (42709, 25)
#
# Remaining columns:
# 1. Delivery_person_Age
# 2. Delivery_person_Ratings
# 3. Weatherconditions
# 4. Road_traffic_density
# 5. Vehicle_condition
# 6. Type_of_order
# 7. Type_of_vehicle
# 8. multiple_deliveries
# 9. Festival
# 10. City
# 11. Time_taken(min)
# 12. distance_km
# 13. Order_Hour
# 14. Order_Minute
# 15. Order_Day
# 16. Order_Month
# 17. Order_DayOfWeek
# 18. Time_Period
# 19. Is_Weekend
# 20. Time_Order_Missing
# 21. Pickup_Delay_Min
# 22. Pickup_Delay_Missing
# 23. Pickup_Hour
# 24. Pickup_Minute
# 25. Pickup_Time_Period

# %%
#Encoding and training
# Separate input features and target

X = df.drop(columns=["Time_taken(min)"])
y = df["Time_taken(min)"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (42709, 24)
# y shape: (42709,)

# %%
# Columns with a natural order
ordinal_cols = [
    "Road_traffic_density",
    "Time_Period",
    "Pickup_Time_Period"
]

# Columns without a natural order
onehot_cols = [
    "Weatherconditions",
    "Type_of_order",
    "Type_of_vehicle",
    "Festival",
    "City"
]

# %%
for col in ordinal_cols:
    print(f"\n--- {col} ---")
    print(X[col].unique())
# Out:
# --- Road_traffic_density ---
# ['High' 'Jam' 'Low' 'Medium' 'Unknown']
#
# --- Time_Period ---
# ['Morning' 'Evening' 'Afternoon' 'Night' 'Unknown']
#
# --- Pickup_Time_Period ---
# ['Morning' 'Evening' 'Afternoon' 'Night']

# %%
#Breaking data for training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (34167, 24)
# X_test : (8542, 24)
# y_train: (34167,)
# y_test : (8542,)

# %%
#Making encoder??
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer

ordinal_categories = [
    ["Low", "Medium", "High", "Jam", "Unknown"],       # Road_traffic_density
    ["Morning", "Afternoon", "Evening", "Night", "Unknown"],  # Time_Period
    ["Morning", "Afternoon", "Evening", "Night"]        # Pickup_Time_Period
]

ordinal_encoder = OrdinalEncoder(
    categories=ordinal_categories,
    handle_unknown="use_encoded_value",
    unknown_value=-1
)

onehot_encoder = OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=False
)

# %%
#Transformer
preprocessor = ColumnTransformer(
    transformers=[
        ("ordinal", ordinal_encoder, ordinal_cols),
        ("onehot", onehot_encoder, onehot_cols)
    ],
    remainder="passthrough"
)

# %%
#Fitting
X_train_encoded = preprocessor.fit_transform(X_train)

# Transform test data using the already-fitted preprocessor
X_test_encoded = preprocessor.transform(X_test)

print("Encoded X_train shape:", X_train_encoded.shape)
print("Encoded X_test shape :", X_test_encoded.shape)
# Out:
# Encoded X_train shape: (34167, 41)
# Encoded X_test shape : (8542, 41)

# %%
# Linear Regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

linear_model = LinearRegression()

# Train
linear_model.fit(X_train_encoded, y_train)

# Predict
y_pred_linear = linear_model.predict(X_test_encoded)

# Evaluation
mae_linear = mean_absolute_error(y_test, y_pred_linear)
rmse_linear = np.sqrt(mean_squared_error(y_test, y_pred_linear))
r2_linear = r2_score(y_test, y_pred_linear)

print("Linear Regression Performance")
print("--------------------------------")
print(f"MAE  : {mae_linear:.2f} minutes")
print(f"RMSE : {rmse_linear:.2f} minutes")
print(f"R²   : {r2_linear:.4f}")
print(f"Accuracy (R²): {r2_linear * 100:.2f}%")
# Out:
# Linear Regression Performance
# --------------------------------
# MAE  : 4.78 minutes
# RMSE : 5.98 minutes
# R²   : 0.5795
# Accuracy (R²): 57.95%

# %%
# Decision Tree Regressor

from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor(
    random_state=42,
    max_depth=None
)

# Train
dt_model.fit(X_train_encoded, y_train)

# Predict
y_pred_dt = dt_model.predict(X_test_encoded)

# Evaluation
mae_dt = mean_absolute_error(y_test, y_pred_dt)
rmse_dt = np.sqrt(mean_squared_error(y_test, y_pred_dt))
r2_dt = r2_score(y_test, y_pred_dt)

print("Decision Tree Regressor Performance")
print("------------------------------------")
print(f"MAE      : {mae_dt:.2f} minutes")
print(f"RMSE     : {rmse_dt:.2f} minutes")
print(f"R² Score : {r2_dt:.4f}")
print(f"R² (%)   : {r2_dt * 100:.2f}%")
# Out:
# Decision Tree Regressor Performance
# ------------------------------------
# MAE      : 4.14 minutes
# RMSE     : 5.43 minutes
# R² Score : 0.6524
# R² (%)   : 65.24%

# %%
# XGBoost Regressor

from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

# Train
xgb_model.fit(X_train_encoded, y_train)

# Predict
y_pred_xgb = xgb_model.predict(X_test_encoded)

# Evaluation
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
r2_xgb = r2_score(y_test, y_pred_xgb)

print("XGBoost Regressor Performance")
print("-----------------------------")
print(f"MAE      : {mae_xgb:.2f} minutes")
print(f"RMSE     : {rmse_xgb:.2f} minutes")
print(f"R² Score : {r2_xgb:.4f}")
print(f"R² (%)   : {r2_xgb * 100:.2f}%")
# Out:
# XGBoost Regressor Performance
# -----------------------------
# MAE      : 3.09 minutes
# RMSE     : 3.86 minutes
# R² Score : 0.8249
# R² (%)   : 82.49%

# %%
# LightGBM Regressor

from lightgbm import LGBMRegressor

lgbm_model = LGBMRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=-1,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    verbosity=-1
)

# Train
lgbm_model.fit(X_train_encoded, y_train)

# Predict
y_pred_lgbm = lgbm_model.predict(X_test_encoded)

# Evaluation
mae_lgbm = mean_absolute_error(y_test, y_pred_lgbm)
rmse_lgbm = np.sqrt(mean_squared_error(y_test, y_pred_lgbm))
r2_lgbm = r2_score(y_test, y_pred_lgbm)

print("LightGBM Regressor Performance")
print("------------------------------")
print(f"MAE      : {mae_lgbm:.2f} minutes")
print(f"RMSE     : {rmse_lgbm:.2f} minutes")
print(f"R² Score : {r2_lgbm:.4f}")
print(f"R² (%)   : {r2_lgbm * 100:.2f}%")
# Out:
# LightGBM Regressor Performance
# ------------------------------
# MAE      : 3.07 minutes
# RMSE     : 3.83 minutes
# R² Score : 0.8275
# R² (%)   : 82.75%
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import RandomizedSearchCV

lgbm_base = LGBMRegressor(
    objective="regression",
    random_state=42,
    n_jobs=-1,
    verbosity=-1
)

param_dist = {
    "n_estimators": [100, 200, 300, 500, 700],
    "learning_rate": [0.01, 0.03, 0.05, 0.08, 0.1],
    "num_leaves": [15, 20, 31, 40, 50, 70],
    "max_depth": [-1, 5, 7, 10, 15],
    "min_child_samples": [10, 20, 30, 50, 75],
    "subsample": [0.7, 0.8, 0.9, 1.0],
    "colsample_bytree": [0.7, 0.8, 0.9, 1.0],
    "reg_alpha": [0, 0.01, 0.1, 0.5, 1],
    "reg_lambda": [0, 0.01, 0.1, 0.5, 1]
}

# %%
#Run when want to fine tune the model again
'''lgbm_random = RandomizedSearchCV(
    estimator=lgbm_base,
    param_distributions=param_dist,
    n_iter=30,
    scoring="neg_mean_absolute_error",
    cv=3,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

lgbm_random.fit(X_train_encoded, y_train)'''
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# RandomizedSearchCV(cv=3,
#                    estimator=LGBMRegressor(n_jobs=-1, objective='regression',
#                                            random_state=42, verbosity=-1),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 0.9,
#                                                              1.0],
#                                         'learning_rate': [0.01, 0.03, 0.05,
#                                                           0.08, 0.1],
#                                         'max_depth': [-1, 5, 7, 10, 15],
#                                         'min_child_samples': [10, 20, 30, 50,
#                                                               75],
#                                         'n_estimators': [100, 200, 300, 500,
#                                                          700],
#                                         'num_leaves': [15, 20, 31, 40, 50, 70],
#                                         'reg_alpha': [0, 0.01, 0.1, 0.5, 1],
#                                         'reg_lambda': [0, 0.01, 0.1, 0.5, 1],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=1)

# %%
print("Best Parameters:")
print(lgbm_random.best_params_)

print("\nBest CV MAE:")
print(-lgbm_random.best_score_)
# Out:
# Best Parameters:
# {'subsample': 0.8, 'reg_lambda': 0.01, 'reg_alpha': 1, 'num_leaves': 50, 'n_estimators': 100, 'min_child_samples': 10, 'max_depth': 10, 'learning_rate': 0.1, 'colsample_bytree': 1.0}
#
# Best CV MAE:
# 3.0900213129047693

# %%
best_lgbm = lgbm_random.best_estimator_

# %%
y_pred_lgbm_tuned = best_lgbm.predict(X_test_encoded)
print("Predictions generated:", len(y_pred_lgbm_tuned))
# Out:
# Predictions generated: 8542
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
# Evaluate tuned LightGBM

mae_lgbm_tuned = mean_absolute_error(y_test, y_pred_lgbm_tuned)
rmse_lgbm_tuned = np.sqrt(mean_squared_error(y_test, y_pred_lgbm_tuned))
r2_lgbm_tuned = r2_score(y_test, y_pred_lgbm_tuned)

print("Tuned LightGBM Performance")
print("--------------------------")
print(f"MAE      : {mae_lgbm_tuned:.2f} minutes")
print(f"RMSE     : {rmse_lgbm_tuned:.2f} minutes")
print(f"R² Score : {r2_lgbm_tuned:.4f}")
print(f"R² (%)   : {r2_lgbm_tuned * 100:.2f}%")
# Out:
# Tuned LightGBM Performance
# --------------------------
# MAE      : 3.05 minutes
# RMSE     : 3.81 minutes
# R² Score : 0.8295
# R² (%)   : 82.95%

# %%
# Create comparison table with tuned LightGBM
results = [{
    "Model": "LightGBM Tuned",
    "MAE": mae_lgbm_tuned,
    "RMSE": rmse_lgbm_tuned,
    "R2": r2_lgbm_tuned,
    "R2 (%)": r2_lgbm_tuned * 100
}]

results_df = pd.DataFrame(results)

print("Model Comparison")
print("================")
print(
    results_df
    .sort_values("MAE")
    .to_string(index=False)
)
# Out:
# Model Comparison
# ================
#          Model      MAE     RMSE       R2    R2 (%)
# LightGBM Tuned 3.053067 3.806588 0.829497 82.949717

# %%
# RandomizedSearchCV(...) was time consuming so this is a direct model using parameeters we already found
best_lgbm = LGBMRegressor(
    subsample=0.8,
    reg_lambda=0.01,
    reg_alpha=1,
    num_leaves=50,
    n_estimators=100,
    min_child_samples=10,
    max_depth=10,
    learning_rate=0.1,
    colsample_bytree=1.0,
    random_state=42
)

best_lgbm.fit(X_train_encoded, y_train)

y_pred_lgbm_tuned = best_lgbm.predict(X_test_encoded)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
mae_lgbm_tuned = mean_absolute_error(y_test, y_pred_lgbm_tuned)
rmse_lgbm_tuned = np.sqrt(mean_squared_error(y_test, y_pred_lgbm_tuned))
r2_lgbm_tuned = r2_score(y_test, y_pred_lgbm_tuned)

print("Final Tuned LightGBM")
print("-------------------")
print(f"MAE  : {mae_lgbm_tuned:.2f} minutes")
print(f"RMSE : {rmse_lgbm_tuned:.2f} minutes")
print(f"R²   : {r2_lgbm_tuned:.4f}")
print(f"R² % : {r2_lgbm_tuned * 100:.2f}%")
# Out:
# Final Tuned LightGBM
# -------------------
# MAE  : 3.05 minutes
# RMSE : 3.81 minutes
# R²   : 0.8295
# R² % : 82.95%
